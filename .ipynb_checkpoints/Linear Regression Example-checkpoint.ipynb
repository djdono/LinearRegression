# %%
import pandas as pd
import numpy as np
import os
os.chdir(r'C:\Users\Daniel\Documents\Python Scripts\Kaggle')

# %%
def predict(x, w, b):
    return x*w+b

# %%
def cost_func(x, y, w, b):
    total_error = 0.0
    for i in range(len(x)):
        total_error += (y[i] - (w*x[i] +b))**2
        
    mse = total_error/(len(x))
    return mse

# %%
def update_weights(x, y, w, b, eta):
    weight_deriv = 0
    bias_deriv = 0
    
    for i in range(len(x)):
        weight_deriv += -2*x[i] * (y[i] - (w*x[i] +b))
        bias_deriv += -2*(y[i] - (w*x[i] + b))
    
    w -= (weight_deriv/len(x)) * eta
    b -= (bias_deriv/len(x)) * eta
    
    return w,b

# %%
def train(x, y, w, b, eta, iters):
    cost_history = []
    
    for i in range(iters):
        w,b = update_weights(x, y, w, b, eta)
        cost = cost_func(x, y, w, b)
        cost_history.append(cost)
        
        if i% 5 == 0:
            print(' iter={:d}, weight={:.2}, bias = {:.4f}, cost = {:.2}'.format(i, w, b, cost))
    return w,b, cost_history

# %%
adv = pd.read_csv('advertising.csv')

# %%
sales = list(adv['Sales'])
radio = list(adv['Radio'])

# %%
type(radio)
# Out:
# list

# %%
weights, bias, history = train(sales, radio, 1, 1, .01, 50)
# Out:
#  iter=0, weight=-1.1, bias = 0.8573, cost = 1.9e+03
#  iter=5, weight=-2.3e+04, bias = -1333.0337, cost = 1.3e+11
#  iter=10, weight=-2e+08, bias = -11755854.1654, cost = 1e+19
#  iter=15, weight=-1.8e+12, bias = -103601220575.6344, cost = 8e+26
#  iter=20, weight=-1.5e+16, bias = -913009976132787.1250, cost = 6.2e+34
#  iter=25, weight=-1.4e+20, bias = -8046113857348502528.0000, cost = 4.8e+42
#  iter=30, weight=-1.2e+24, bias = -70908259381384686075904.0000, cost = 3.7e+50
#  iter=35, weight=-1.1e+28, bias = -624895612669672426401955840.0000, cost = 2.9e+58
#  iter=40, weight=-9.3e+31, bias = -5507038674204448631985138565120.0000, cost = 2.3e+66
#  iter=45, weight=-8.2e+35, bias = -48532065747139267756625249471299584.0000, cost = 1.8e+74

# %%
weights
# Out:
# -1.1790375233924801e+39

# %%
bias
# Out:
# -6.952120610489653e+37

# %%
update_weights(radio, sales, 1, 1, .1)
# Out:
# (81.90326000000007, 2.8266999999999998)

# %%
sales
# Out:
# [22.1,
#  10.4,
#  12.0,
#  16.5,
#  17.9,
#  7.2,
#  11.8,
#  13.2,
#  4.8,
#  15.6,
#  12.6,
#  17.4,
#  9.2,
#  13.7,
#  19.0,
#  22.4,
#  12.5,
#  24.4,
#  11.3,
#  14.6,
#  18.0,
#  17.5,
#  5.6,
#  20.5,
#  9.7,
#  17.0,
#  15.0,
#  20.9,
#  18.9,
#  10.5,
#  21.4,
#  11.9,
#  13.2,
#  17.4,
#  11.9,
#  17.8,
#  25.4,
#  14.7,
#  10.1,
#  21.5,
#  16.6,
#  17.1,
#  20.7,
#  17.9,
#  8.5,
#  16.1,
#  10.6,
#  23.2,
#  19.8,
#  9.7,
#  16.4,
#  10.7,
#  22.6,
#  21.2,
#  20.2,
#  23.7,
#  5.5,
#  13.2,
#  23.8,
#  18.4,
#  8.1,
#  24.2,
#  20.7,
#  14.0,
#  16.0,
#  11.3,
#  11.0,
#  13.4,
#  18.9,
#  22.3,
#  18.3,
#  12.4,
#  8.8,
#  11.0,
#  17.0,
#  8.7,
#  6.9,
#  14.2,
#  5.3,
#  11.0,
#  11.8,
#  17.3,
#  11.3,
#  13.6,
#  21.7,
#  20.2,
#  12.0,
#  16.0,
#  12.9,
#  16.7,
#  14.0,
#  7.3,
#  19.4,
#  22.2,
#  11.5,
#  16.9,
#  16.7,
#  20.5,
#  25.4,
#  17.2,
#  16.7,
#  23.8,
#  19.8,
#  19.7,
#  20.7,
#  15.0,
#  7.2,
#  12.0,
#  5.3,
#  19.8,
#  18.4,
#  21.8,
#  17.1,
#  20.9,
#  14.6,
#  12.6,
#  12.2,
#  9.4,
#  15.9,
#  6.6,
#  15.5,
#  7.0,
#  16.6,
#  15.2,
#  19.7,
#  10.6,
#  6.6,
#  11.9,
#  24.7,
#  9.7,
#  1.6,
#  17.7,
#  5.7,
#  19.6,
#  10.8,
#  11.6,
#  9.5,
#  20.8,
#  9.6,
#  20.7,
#  10.9,
#  19.2,
#  20.1,
#  10.4,
#  12.3,
#  10.3,
#  18.2,
#  25.4,
#  10.9,
#  10.1,
#  16.1,
#  11.6,
#  16.6,
#  16.0,
#  20.6,
#  3.2,
#  15.3,
#  10.1,
#  7.3,
#  12.9,
#  16.4,
#  13.3,
#  19.9,
#  18.0,
#  11.9,
#  16.9,
#  8.0,
#  17.2,
#  17.1,
#  20.0,
#  8.4,
#  17.5,
#  7.6,
#  16.7,
#  16.5,
#  27.0,
#  20.2,
#  16.7,
#  16.8,
#  17.6,
#  15.5,
#  17.2,
#  8.7,
#  26.2,
#  17.6,
#  22.6,
#  10.3,
#  17.3,
#  20.9,
#  6.7,
#  10.8,
#  11.9,
#  5.9,
#  19.6,
#  17.3,
#  7.6,
#  14.0,
#  14.8,
#  25.5,
#  18.4]

# %%
radio
# Out:
# [37.8,
#  39.3,
#  45.9,
#  41.3,
#  10.8,
#  48.9,
#  32.8,
#  19.6,
#  2.1,
#  2.6,
#  5.8,
#  24.0,
#  35.1,
#  7.6,
#  32.9,
#  47.7,
#  36.6,
#  39.6,
#  20.5,
#  23.9,
#  27.7,
#  5.1,
#  15.9,
#  16.9,
#  12.6,
#  3.5,
#  29.3,
#  16.7,
#  27.1,
#  16.0,
#  28.3,
#  17.4,
#  1.5,
#  20.0,
#  1.4,
#  4.1,
#  43.8,
#  49.4,
#  26.7,
#  37.7,
#  22.3,
#  33.4,
#  27.7,
#  8.4,
#  25.7,
#  22.5,
#  9.9,
#  41.5,
#  15.8,
#  11.7,
#  3.1,
#  9.6,
#  41.7,
#  46.2,
#  28.8,
#  49.4,
#  28.1,
#  19.2,
#  49.6,
#  29.5,
#  2.0,
#  42.7,
#  15.5,
#  29.6,
#  42.8,
#  9.3,
#  24.6,
#  14.5,
#  27.5,
#  43.9,
#  30.6,
#  14.3,
#  33.0,
#  5.7,
#  24.6,
#  43.7,
#  1.6,
#  28.5,
#  29.9,
#  7.7,
#  26.7,
#  4.1,
#  20.3,
#  44.5,
#  43.0,
#  18.4,
#  27.5,
#  40.6,
#  25.5,
#  47.8,
#  4.9,
#  1.5,
#  33.5,
#  36.5,
#  14.0,
#  31.6,
#  3.5,
#  21.0,
#  42.3,
#  41.7,
#  4.3,
#  36.3,
#  10.1,
#  17.2,
#  34.3,
#  46.4,
#  11.0,
#  0.3,
#  0.4,
#  26.9,
#  8.2,
#  38.0,
#  15.4,
#  20.6,
#  46.8,
#  35.0,
#  14.3,
#  0.8,
#  36.9,
#  16.0,
#  26.8,
#  21.7,
#  2.4,
#  34.6,
#  32.3,
#  11.8,
#  38.9,
#  0.0,
#  49.0,
#  12.0,
#  39.6,
#  2.9,
#  27.2,
#  33.5,
#  38.6,
#  47.0,
#  39.0,
#  28.9,
#  25.9,
#  43.9,
#  17.0,
#  35.4,
#  33.2,
#  5.7,
#  14.8,
#  1.9,
#  7.3,
#  49.0,
#  40.3,
#  25.8,
#  13.9,
#  8.4,
#  23.3,
#  39.7,
#  21.1,
#  11.6,
#  43.5,
#  1.3,
#  36.9,
#  18.4,
#  18.1,
#  35.8,
#  18.1,
#  36.8,
#  14.7,
#  3.4,
#  37.6,
#  5.2,
#  23.6,
#  10.6,
#  11.6,
#  20.9,
#  20.1,
#  7.1,
#  3.4,
#  48.9,
#  30.2,
#  7.8,
#  2.3,
#  10.0,
#  2.6,
#  5.4,
#  5.7,
#  43.0,
#  21.3,
#  45.1,
#  2.1,
#  28.7,
#  13.9,
#  12.1,
#  41.1,
#  10.8,
#  4.1,
#  42.0,
#  35.6,
#  3.7,
#  4.9,
#  9.3,
#  42.0,
#  8.6]
